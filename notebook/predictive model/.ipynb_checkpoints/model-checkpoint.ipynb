# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("../../data/processed/cap-3.csv")
df=df.drop("Unnamed: 0",axis=1)
df.head()
# Out:
#    Merit No  Marks  Application ID           Name of Candidate Gender  \
# 0        60  95.13        19106856  PAWAR SIDDHI RAVINDRASINGH      F
# 1       213  93.38        19126045   MAHALLE SHRADDHA MOHANRAO      F
# 2       384  92.47        19105661        TUSHAR RAJESH LAHANE      M
# 3       420  92.31        19103256         RAUT PALASH SUBHASH      M
# 4       846  90.79        19148502   BIRAJDAR SAURABH DAYANAND      M
#
#   Category  Category id Seat Type PWD/DEF  Sub Group sub group name  \
# 0     OPEN            1     LOPEN     NaN        201          Civil
# 1      OBC            2     GOPEN     NaN        201          Civil
# 2      OBC            2      GOBC     NaN        201          Civil
# 3      OBC            2      GOBC     NaN        201          Civil
# 4     SEBC            3     GSEBC     NaN        201          Civil
#
#    cource_code cource code name  college_code Institute dict  \
# 0          201            Civil          1002       Amravati
# 1          201            Civil          1002       Amravati
# 2          201            Civil          1002       Amravati
# 3          201            Civil          1002       Amravati
# 4          201            Civil          1002       Amravati
#
#                                 Institute Name Seat conformation  \
# 0  Government College of Engineering, Amravati                 ^
# 1  Government College of Engineering, Amravati                 ^
# 2  Government College of Engineering, Amravati                 ^
# 3  Government College of Engineering, Amravati                 ^
# 4  Government College of Engineering, Amravati                 ^
#
#    Seat conformation id
# 0                   1.0
# 1                   1.0
# 2                   1.0
# 3                   1.0
# 4                   1.0

# %%
df.corr()
# Out:
#                       Merit No     Marks  Application ID  Category id  \
# Merit No              1.000000  0.540966        0.703967     0.412531
# Marks                 0.540966  1.000000        0.977275     0.553842
# Application ID        0.703967  0.977275        1.000000     0.570479
# Category id           0.412531  0.553842        0.570479     1.000000
# Sub Group             0.650388  0.890029        0.912145     0.500171
# cource_code           0.650224  0.895341        0.917514     0.502768
# college_code          0.586906  0.843347        0.857992     0.499533
# Seat conformation id  0.093338 -0.107446        0.006627    -0.040615
#
#                       Sub Group  cource_code  college_code  \
# Merit No               0.650388     0.650224      0.586906
# Marks                  0.890029     0.895341      0.843347
# Application ID         0.912145     0.917514      0.857992
# Category id            0.500171     0.502768      0.499533
# Sub Group              1.000000     0.991266      0.800270
# cource_code            0.991266     1.000000      0.800999
# college_code           0.800270     0.800999      1.000000
# Seat conformation id  -0.029632    -0.024176      0.035980
#
#                       Seat conformation id
# Merit No                          0.093338
# Marks                            -0.107446
# Application ID                    0.006627
# Category id                      -0.040615
# Sub Group                        -0.029632
# cource_code                      -0.024176
# college_code                      0.035980
# Seat conformation id              1.000000

# %%
cormat=df.corr()
top_cor_feature=cormat.index
plt.figure(figsize=(15,15))
sns.heatmap(df[top_cor_feature].corr(),annot=True,cmap="RdYlGn")
