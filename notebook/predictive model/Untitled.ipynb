# %%
import pandas as pd
import sys
df=pd.read_csv("../../data/processed/dist data/Pune/cast/OPEN.csv")
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Merit No  Marks  Application ID  \
# 0           2           473      3893  85.70        19136678
# 1          31           503     20977  72.91        19144210
# 2          32           504     27390  69.76        19141842
# 3          34           506     29139  68.97        19119195
# 4          36           508     34294  66.73        19118619
#
#                Name of Candidate Gender Category  Category id Seat Type  \
# 0  KHANDAGALE DATTATRAY SHRIKANT      M     OPEN            1     GOPEN
# 1     SURYADITYA AMARSHINA PATIL      M     OPEN            1     GOPEN
# 2        THAKUR RITESH PANDURANG      M     OPEN            1     GOPEN
# 3            ASIF MUBARAK BAGWAN      M     OPEN            1     GOPEN
# 4             THETE AKSHAY KISAN      M     OPEN            1     GOPEN
#
#   PWD/DEF  Sub Group sub group name  cource_code cource code name  \
# 0     NaN        101       Chemical          101         Chemical
# ...

# %%
def student_classifaction(dist,cast):
    course=101
    gender="M"
    df=pd.read_csv("../../data/processed/dist data/Pune/cast/OPEN.csv")
    g=df[df["Gender"]==gender].index.values
    c=df[df["cource code name"]==course].index.values
    print(g)
              
student_classifaction("Pune","Open")
# Out:
# [   0    1    2 ... 4340 4341 4342]
