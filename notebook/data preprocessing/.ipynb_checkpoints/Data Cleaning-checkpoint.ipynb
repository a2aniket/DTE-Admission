# %% [markdown]
# # Data Cleaning

# %%
import pandas as pd
import numpy as np

# %%
dataframe=pd.read_csv("../../data/raw/cap-1 student info.csv")
dataframe.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Sr.No. Merit No   Marks Application ID  \
# 0           0             0       1       60  95.13%    DSE19106856
# 1           1             1       2      213  93.38%    DSE19126045
# 2           2             2       3      384  92.47%    DSE19105661
# 3           3             3       4      420  92.31%    DSE19103256
# 4           4             4       5      465  92.12%    DSE19147230
#
#             Name of Candidate Gender Category PWD/DEF Sub Group Seat Type  \
# 0  PAWAR SIDDHI RAVINDRASINGH      F     OPEN     NaN       201     LOPEN
# 1   MAHALLE SHRADDHA MOHANRAO      F      OBC     NaN       201     GOPEN
# 2        TUSHAR RAJESH LAHANE      M      OBC     NaN       201      GOBC
# 3         RAUT PALASH SUBHASH      M      OBC     NaN       201      GOBC
# 4   INGLE DHANASHRI VIJAYSINH      F     SEBC     NaN       201     GSEBC
#
#    cource_code  college_code
# 0          201          1002
# 1          201          1002
# 2          201          1002
# 3          201          1002
# 4          201          1002

# %%
dataframe.drop(["Unnamed: 0","Unnamed: 0.1"],axis=1,inplace=True)

# %% [markdown]
# ## Feature clearing

# %% [markdown]
# ### Feature ["Mert No"]

# %% [markdown]
# Marks have some vacant anoted by "-" they showd be convertd as 0

# %%
dataframe["Merit No"]=dataframe["Merit No"].astype(str)
vacent_entres=dataframe[dataframe["Merit No"]=="-"].index.values
dataframe.iloc[vacent_entres]=0

# %% [markdown]
# The feature mert no have all the integer feature it shoud be integer

# %%
dataframe["Merit No"] = pd.to_numeric(dataframe["Merit No"], errors='coerce').fillna(0).astype(np.int64)

# %% [markdown]
# ### Feature [Marks]

# %% [markdown]
# The marks in format of % eg 80.0% they should converted as 80.0

# %%
dataframe["Marks"]=dataframe["Marks"].astype(str)

# %%
length=dataframe.shape
length[0]
# Out:
# 75031

# %% [markdown]
# removig %

# %%
for i in range(length[0]):
    data=dataframe["Marks"].iloc[i]
    if data!=0:
        data=''.join([ word for word  in data if word.isdigit() or word=="."])
        dataframe["Marks"].iloc[i]=data
# Out:
# C:\Users\shubham\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
dataframe["Marks"] = pd.to_numeric(dataframe["Marks"], errors='coerce').fillna(0).astype(np.float64)

# %% [markdown]
# ### Feature [Application Id]

# %% [markdown]
# The application id is only the feature that can uniqly identify student bot the application id is in format DSE12458. if move remove [DSE] from the if goood o have id as Integer

# %%
dataframe["Application ID"]=dataframe["Application ID"].astype(str)

# %%
for i in range(length[0]):
    data=dataframe["Application ID"].iloc[i]
    if  data !=0:
        data=''.join([word for word in data if  word.isdigit()])
        dataframe["Application ID"].iloc[i]=data

# %%
dataframe["Application ID"] = pd.to_numeric(dataframe["Application ID"], errors='coerce').fillna(0).astype(np.int64)

# %% [markdown]
# ### Feature [Seat Type]

# %% [markdown]
# The feature seat type contain the spacial symobols witch can affect model.It better to remove the symboles

# %%
dataframe["Seat Type"]=dataframe["Seat Type"].astype(str)

# %%
dataframe["Seat conformation"]=np.nan
for i in range(length[0]):
    data=dataframe["Seat Type"].iloc[i]
    if data!=0:
        data=''.join([word for word in data if not word.isalnum()])
        dataframe["Seat conformation"].iloc[i]=data

# %%
for i in range(length[0]):
    data=dataframe["Seat Type"].iloc[i]
    if data!=0:
        data=''.join([word for word in data if word.isalpha()])
        dataframe["Seat Type"].iloc[i]=data

# %%
dataframe["Seat conformation"].unique()
# Out:
# array([''], dtype=object)

# %%
seat_conformation=({    
    '^':1,
    '#':2,
    '*':3,
    '*-':3,
    '&':4,
    '&-':4,
    '@':5,
})
dataframe["Seat conformation id "]=dataframe["Seat conformation"].map(seat_conformation)

# %%
dataframe["Seat Type"].unique()
# Out:
# array(['LOPEN', 'GOPEN', 'GOBC', 'GSEBC', 'EWS', 'LSC', 'LST', 'GSC', '',
#        'LOBC', 'GST', 'GNTD', 'LSEBC', 'LNTC', 'PHOBC', 'LNTB', 'MI',
#        'GNTB', 'GNTC', 'GNTA', 'LNTA', 'DFSC', 'LNTD', 'PHO', 'DFSEBC',
#        'DFO', 'PHSC', 'DFOBC', 'DFNTC', 'DFNTD', 'PHNTC', 'PHSEBC',
#        'PHNTB', 'PHNTA', 'DFST', 'DFNTB', 'PHNTD'], dtype=object)

# %% [markdown]
# ### Feature [Category]

# %% [markdown]
# The feature invalid symboles

# %%
for i in range(length[0]):
    data=dataframe["Category"].iloc[i]
    if data!=0:
        data=''.join([word for word in data if word.isalpha() or word.isdigit() or word == "/" or word=="(" or word==")"])
        dataframe["Category"].iloc[i]=data

# %%
dataframe["Category"].unique()
# Out:
# array(['OPEN', 'OBC', 'SEBC', 'OPEN/EWS', 'SC', 'ST', 'NT1(NTB)', 0,
#        'NT3(NTD)', 'NT2(NTC)', 'SBC/OBC', 'DT/VJNT(A)', 'SBC', '0'],
#       dtype=object)

# %%
category_unique=dict({
    "OPEN":"OPEN",
    "OBC":"OBC",
    "SEBC":"SEBC",
    "SC":"SC",
    "OPEN/EWS":"OPEN/EWS",
    "ST":"ST",
    "NT1(NTB)":"NT1",
    "NT2(NTC)":"NT2",
    "NT3(NTD)":"NT3",
    "SBC/OBC":"SBC/OBC",
    "DT/VJNT(A)":"DT/VJNT(A)",
    "SBC":"SBC"
})

dataframe["Category"]=dataframe["Category"].map(category_unique)

# %%
dataframe["Category"].unique()
# Out:
# array(['OPEN', 'OBC', 'SEBC', 'OPEN/EWS', 'SC', 'ST', 'NT1', nan, 'NT3',
#        'NT2', 'SBC/OBC', 'DT/VJNT(A)', 'SBC'], dtype=object)

# %%
category_unique=dict({
    "OPEN":1,
    "OBC":2,
    "SEBC":3,
    "SC":4,
    "OPEN/EWS":5,
    "ST":6,
    "NT1":7,
    "NT2":8,
    "NT3":9,
    "SBC/OBC":10,
    "DT/VJNT(A)":11,
    "SBC":12
})
dataframe["Category id"]=dataframe["Category"].map(category_unique)

# %%
dataframe["Category id"] = pd.to_numeric(dataframe["Category id"], errors='coerce').fillna(0).astype(np.int64)

# %%
dataframe["Category id"].unique()
# Out:
# array([ 1,  2,  3,  5,  4,  6,  7,  0,  9,  8, 10, 11, 12], dtype=int64)

# %% [markdown]
# ###  Feature [Gender]

# %%
dataframe["Gender"]=dataframe["Gender"].astype(str)

# %% [markdown]
# ### Feature [PWD/DEF]

# %% [markdown]
# PWD/DEF invalis carater such as /n /r

# %%
dataframe["PWD/DEF"].unique()
# Out:
# array([nan, 0, 'Low-Vision', 'DEF1', 'Locomotor \r\nDisability',
#        'Physical \r\nimpairment', 'DEF2', 'Hard of \r\nHearing',
#        'Thalassemia', '0', 'Specific \r\nLearning \r\nDisabilities',
#        'Cerebral \r\nPalsy', 'Blindness', 'DEF3', 'Haemophilia',
#        'Muscular \r\nDystrophy', 'Physical \r\nimpairment/DEF1', 'Deaf',
#        'Intellectual \r\nDisability'], dtype=object)

# %%
pwd_def=dict({
  "Locomotor \r\nDisability":"Locomotor Disability",
  "Physical \r\nimpairment":"Physical impairment",
  "Hard of \r\nHearing":"Hard of Hearing",
  "Specific \r\nLearning \r\nDisabilities":"Specific Learning Disabilities",
  "Cerebral \r\nPalsy":"Cerebral Palsy",
  "Muscular \r\nDystrophy":"Muscular Dystrophy",
  "Physical \r\nimpairment/DEF1":"Physical impairment DEF1",
  "Intellectual \r\nDisability":"Intellectual Disability"
})
dataframe["PWD/DEF"]=dataframe["PWD/DEF"].map(pwd_def)

# %%
dataframe["PWD/DEF"].unique()
# Out:
# array([nan, 'Locomotor Disability', 'Physical impairment',
#        'Hard of Hearing', 'Specific Learning Disabilities',
#        'Cerebral Palsy', 'Muscular Dystrophy', 'Physical impairment DEF1',
#        'Intellectual Disability'], dtype=object)

# %% [markdown]
# ### Feature [Sub Group]

# %%
dataframe["Sub Group"]=dataframe["Sub Group"].astype(str)
for i in range(length[0]):
    code=dataframe["Sub Group"].iloc[i]
    dataframe["Sub Group"].iloc[i]=code[-3:].lower()

# %%
dataframe["Sub Group"].unique()
# Out:
# array(['201', '101', '104', '0', '102', '401', '103', '701', '404', '702',
#        '304', '302', '301', '1.0', '303', '501', '305', '402', '403',
#        '801', '601'], dtype=object)

# %%
dataframe["Sub Group"] = pd.to_numeric(dataframe["Sub Group"], errors='coerce').fillna(0).astype(np.int64)

# %%
cource_data=({   
    101:"Chemical",
    102:"Plastic",
    103:"Food Technology",
    104:"Oil and Paints Technology",
    105:"",
    201 :"Civil",
    301:"Computer & IT",
    303:" Medical Electronics",
    304:"Electrical",
    302:"ENTC",
    305:"Instrumentation",
    401:"Machanical",
    402:"Production",
    403:"Packaging Technology",
    404:"Metallurgy (Foundry Technology)",
    405:"Aeronautical Engineering",
    501:"Mining",
    601:"Printing Technology",
    701:"Knitting Technology",
    702:"Man made Textile Chemistry",
})
dataframe["sub group name"]=dataframe["Sub Group"].map(cource_data)
dataframe["cource code name"]=dataframe["cource_code"].map(cource_data)

# %% [markdown]
# ### Add College Name

# %% [markdown]
# The data scource only have college code we have to add collage name

# %%
college_data=pd.read_csv("../../data/raw/college maping.csv",index_col=["Institute Code"],usecols=None,)
college_data.drop(["Unnamed: 0"],axis=1,inplace=True)
college_data.head()
# Out:
#                                                    Institute Name
# Institute Code
# 1002                  Government College of Engineering, Amravati
# 1005                 Sant Gadge Baba Amravati University,Amravati
# 1012                     Government Engineering College, Yavatmal
# 1101            Shri Sant Gajanan Maharaj College of Engineeri...
# 1105            Prof. Ram Meghe Institute of Technology & Rese...

# %%
data=college_data.to_dict()
data=data['Institute Name']

# %%
dataframe["Institute Name"]=dataframe["college_code"].map(data)

# %%
dataframe.head(100)
# Out:
#     Sr.No.  Merit No  Marks  Application ID           Name of Candidate  \
# 0        1        60  95.13        19106856  PAWAR SIDDHI RAVINDRASINGH
# 1        2       213  93.38        19126045   MAHALLE SHRADDHA MOHANRAO
# 2        3       384  92.47        19105661        TUSHAR RAJESH LAHANE
# 3        4       420  92.31        19103256         RAUT PALASH SUBHASH
# 4        5       465  92.12        19147230   INGLE DHANASHRI VIJAYSINH
# ..     ...       ...    ...             ...                         ...
# 95       0         0   0.00               0                           0
# 96       0         0   0.00               0                           0
# 97       0         0   0.00               0                           0
# 98       0         0   0.00               0                           0
# 99       0         0   0.00               0                           0
#
#    Gender Category PWD/DEF  Sub Group Seat Type  cource_code  college_code  \
# 0       F     OPEN     NaN        201     LOPEN          201          1002
# 1       F      OBC     NaN        201     GOPEN          201          1002
# 2       M      OBC     NaN        201      GOBC          201          1002
# 3       M      OBC     NaN        201      GOBC          201          1002
# 4       F     SEBC     NaN        201     GSEBC          201          1002
# ..    ...      ...     ...        ...       ...          ...           ...
# 95      0      NaN     NaN          0                      0             0
# 96      0      NaN     NaN          0                      0             0
# 97      0      NaN     NaN          0                      0             0
# 98      0      NaN     NaN          0                      0             0
# 99      0      NaN     NaN          0                      0             0
#
#    Seat conformation  Seat conformation id   Category id sub group name  \
# 0                                       NaN            1          Civil
# 1                                       NaN            2          Civil
# 2                                       NaN            2          Civil
# 3                                       NaN            2          Civil
# 4                                       NaN            3          Civil
# ..               ...                    ...          ...            ...
# 95                                      NaN            0            NaN
# 96                                      NaN            0            NaN
# 97                                      NaN            0            NaN
# 98                                      NaN            0            NaN
# 99                                      NaN            0            NaN
#
#    cource code name                               Institute Name
# 0             Civil  Government College of Engineering, Amravati
# 1             Civil  Government College of Engineering, Amravati
# 2             Civil  Government College of Engineering, Amravati
# 3             Civil  Government College of Engineering, Amravati
# 4             Civil  Government College of Engineering, Amravati
# ..              ...                                          ...
# 95              NaN                                          NaN
# 96              NaN                                          NaN
# 97              NaN                                          NaN
# 98              NaN                                          NaN
# 99              NaN                                          NaN
#
# [100 rows x 18 columns]

# %% [markdown]
# ###  College city

# %%
city=pd.read_csv("../../data/raw/college town.csv",index_col=["Institute Code"])
city.drop(["Unnamed: 0"],axis=1,inplace=True)
city.head()
# Out:
#                Institute dict
# Institute Code
# 1002                 Amravati
# 1005                 Amravati
# 1012                 Yavatmal
# 1101                 Buldhana
# 1105                 Amravati

# %%
dataframe["Institute dict"]=np.nan
city=city.to_dict()
city=city["Institute dict"]
dataframe["Institute dict"]=dataframe["college_code"].map(city)

# %%
dataframe.head(50)
# Out:
#     Sr.No.  Merit No  Marks  Application ID               Name of Candidate  \
# 0        1        60  95.13        19106856      PAWAR SIDDHI RAVINDRASINGH
# 1        2       213  93.38        19126045       MAHALLE SHRADDHA MOHANRAO
# 2        3       384  92.47        19105661            TUSHAR RAJESH LAHANE
# 3        4       420  92.31        19103256             RAUT PALASH SUBHASH
# 4        5       465  92.12        19147230       INGLE DHANASHRI VIJAYSINH
# 5        6       585  91.70        19140012         PATHAN MUJAHID NAJEKHAN
# 6        7      1941  88.47        19108714         GHUGARE SAKSHI RAVINDRA
# 7        8      8635  81.09        19115650       KOKATE SATYABHAMA PRALHAD
# 8        1     35011  66.42        19139779          SHWETA FULCHAND SHENDE
# 9        2     46850  61.16        19145385        GAWANDE RUSHIKESH KESHAV
# 10       3     48144  60.42        19131759           SHINDE VIRENDRA SUNIL
# 11       0         0   0.00               0                               0
# 12       0         0   0.00               0                               0
# 13       0         0   0.00               0                               0
# 14       0         0   0.00               0                               0
# 15       0         0   0.00               0                               0
# 16       0         0   0.00               0                               0
# 17       0         0   0.00               0                               0
# 18       1       669  91.38        19130005              CHOURE SUDHIR BALU
# 19       2     15901  75.82        19137673          PAWAR SOURABH SAKHARAM
# 20       3     18174  74.67        19109361             KHAPRE ONKAR PRAMOD
# 21       4     32159  67.64        19130850           TAYDE RESHAMA SANTOSH
# 22       5     40081  64.30        19150865              DARSHAN ARUN BORSE
# 23       6     40507  64.12        19122063          BORULE SAGAR MURLIDHAR
# 24       7     49003  60.00        19124924        MAHADOLE SAURABH BHAGWAN
# 25       8     51387  58.06        19111566          VIPUL BHAJANDAS TADOSE
# 26       1      4377  85.17        19115987            AMBHORE ARJUN SANJAY
# 27       2     12955  77.82        19154765        SANGLE INDRAMOHAN ASARAM
# 28       3     19939  73.45        19154549               DETHE SAGAR ARJUN
# 29       4     31098  68.06        19150706        BUDALE AVINASH VIRBHADRA
# 30       5     32160  67.64        19109553           WAGH SHUBHAM GAJENDRA
# 31       6     41004  63.88        19103901        LODH ARYA CHANDRASHEKHAR
# 32       7     42915  63.06        19142515  MOHD ATIF AHMAD ASHFAQUE AHMAD
# 33       8     45167  62.00        19149833      BAGAL DNYANESHWAR HANUMANT
# 34       9     45571  61.81        19105024               CHALE VIVEK DIPAK
# 35      10     53119  55.76        19121063                KANT NIKHIL ANIL
# 36      11     53753  54.25        19156756               GIRI ANUJA GANESH
# 37       0         0   0.00               0                               0
# 38       0         0   0.00               0                               0
# 39       0         0   0.00               0                               0
# 40       0         0   0.00               0                               0
# 41       0         0   0.00               0                               0
# 42       0         0   0.00               0                               0
# 43       0         0   0.00               0                               0
# 44       0         0   0.00               0                               0
# 45       0         0   0.00               0                               0
# 46       0         0   0.00               0                               0
# 47       0         0   0.00               0                               0
# 48       0         0   0.00               0                               0
# 49       0         0   0.00               0                               0
#
#    Gender  Category PWD/DEF  Sub Group Seat Type  cource_code  college_code  \
# 0       F      OPEN     NaN        201     LOPEN          201          1002
# 1       F       OBC     NaN        201     GOPEN          201          1002
# 2       M       OBC     NaN        201      GOBC          201          1002
# 3       M       OBC     NaN        201      GOBC          201          1002
# 4       F      SEBC     NaN        201     GSEBC          201          1002
# 5       M  OPEN/EWS     NaN        201       EWS          201          1002
# 6       F        SC     NaN        201       LSC          201          1002
# 7       F        ST     NaN        201       LST          201          1002
# 8       F       NT1     NaN        101     LOPEN          101          1005
# 9       M        SC     NaN        104       GSC          101          1005
# 10      M      OPEN     NaN        101     GOPEN          101          1005
# 11      0       NaN     NaN          0                      0             0
# 12      0       NaN     NaN          0                      0             0
# 13      0       NaN     NaN          0                      0             0
# 14      0       NaN     NaN          0                      0             0
# 15      0       NaN     NaN          0                      0             0
# 16      0       NaN     NaN          0                      0             0
# 17      0       NaN     NaN          0                      0             0
# 18      M      SEBC     NaN        101     GOPEN          101          1005
# 19      M      SEBC     NaN        101     GOPEN          101          1005
# 20      M      SEBC     NaN        101     GSEBC          101          1005
# 21      F        SC     NaN        101     LOPEN          101          1005
# 22      M        SC     NaN        101       LSC          101          1005
# 23      M       OBC     NaN        101      GOBC          101          1005
# 24      M       OBC     NaN        101      LOBC          101          1005
# 25      M        ST     NaN        201       GST          101          1005
# 26      M       OBC     NaN        102     GOPEN          101          1116
# 27      M       NT3     NaN        101     GOPEN          101          1116
# 28      M        SC     NaN        101     GOPEN          101          1116
# 29      M      OPEN     NaN        101     GOPEN          101          1116
# 30      M      SEBC     NaN        101     GOPEN          101          1116
# 31      M       OBC     NaN        101     GOPEN          101          1116
# 32      M       OBC     NaN        102      GOBC          101          1116
# 33      M      OPEN     NaN        401     LOPEN          101          1116
# 34      M       OBC     NaN        102      GOBC          101          1116
# 35      M      OPEN     NaN        101     GOPEN          101          1116
# 36      F       NT1     NaN        102     LOPEN          101          1116
# 37      0       NaN     NaN          0                      0             0
# 38      0       NaN     NaN          0                      0             0
# 39      0       NaN     NaN          0                      0             0
# 40      0       NaN     NaN          0                      0             0
# 41      0       NaN     NaN          0                      0             0
# 42      0       NaN     NaN          0                      0             0
# 43      0       NaN     NaN          0                      0             0
# 44      0       NaN     NaN          0                      0             0
# 45      0       NaN     NaN          0                      0             0
# 46      0       NaN     NaN          0                      0             0
# 47      0       NaN     NaN          0                      0             0
# 48      0       NaN     NaN          0                      0             0
# 49      0       NaN     NaN          0                      0             0
#
#    Seat conformation  Seat conformation id   Category id  \
# 0                                       NaN            1
# 1                                       NaN            2
# 2                                       NaN            2
# 3                                       NaN            2
# 4                                       NaN            3
# 5                                       NaN            5
# 6                                       NaN            4
# 7                                       NaN            6
# 8                                       NaN            7
# 9                                       NaN            4
# 10                                      NaN            1
# 11                                      NaN            0
# 12                                      NaN            0
# 13                                      NaN            0
# 14                                      NaN            0
# 15                                      NaN            0
# 16                                      NaN            0
# 17                                      NaN            0
# 18                                      NaN            3
# 19                                      NaN            3
# 20                                      NaN            3
# 21                                      NaN            4
# 22                                      NaN            4
# 23                                      NaN            2
# 24                                      NaN            2
# 25                                      NaN            6
# 26                                      NaN            2
# 27                                      NaN            9
# 28                                      NaN            4
# 29                                      NaN            1
# 30                                      NaN            3
# 31                                      NaN            2
# 32                                      NaN            2
# 33                                      NaN            1
# 34                                      NaN            2
# 35                                      NaN            1
# 36                                      NaN            7
# 37                                      NaN            0
# 38                                      NaN            0
# 39                                      NaN            0
# 40                                      NaN            0
# 41                                      NaN            0
# 42                                      NaN            0
# 43                                      NaN            0
# 44                                      NaN            0
# 45                                      NaN            0
# 46                                      NaN            0
# 47                                      NaN            0
# 48                                      NaN            0
# 49                                      NaN            0
#
#                sub group name cource code name  \
# 0                       Civil            Civil
# 1                       Civil            Civil
# 2                       Civil            Civil
# 3                       Civil            Civil
# 4                       Civil            Civil
# 5                       Civil            Civil
# 6                       Civil            Civil
# 7                       Civil            Civil
# 8                    Chemical         Chemical
# 9   Oil and Paints Technology         Chemical
# 10                   Chemical         Chemical
# 11                        NaN              NaN
# 12                        NaN              NaN
# 13                        NaN              NaN
# 14                        NaN              NaN
# 15                        NaN              NaN
# 16                        NaN              NaN
# 17                        NaN              NaN
# 18                   Chemical         Chemical
# 19                   Chemical         Chemical
# 20                   Chemical         Chemical
# 21                   Chemical         Chemical
# 22                   Chemical         Chemical
# 23                   Chemical         Chemical
# 24                   Chemical         Chemical
# 25                      Civil         Chemical
# 26                    Plastic         Chemical
# 27                   Chemical         Chemical
# 28                   Chemical         Chemical
# 29                   Chemical         Chemical
# 30                   Chemical         Chemical
# 31                   Chemical         Chemical
# 32                    Plastic         Chemical
# 33                 Machanical         Chemical
# 34                    Plastic         Chemical
# 35                   Chemical         Chemical
# 36                    Plastic         Chemical
# 37                        NaN              NaN
# 38                        NaN              NaN
# 39                        NaN              NaN
# 40                        NaN              NaN
# 41                        NaN              NaN
# 42                        NaN              NaN
# 43                        NaN              NaN
# 44                        NaN              NaN
# 45                        NaN              NaN
# 46                        NaN              NaN
# 47                        NaN              NaN
# 48                        NaN              NaN
# 49                        NaN              NaN
#
#                                        Institute Name Institute dict
# 0         Government College of Engineering, Amravati       Amravati
# 1         Government College of Engineering, Amravati       Amravati
# 2         Government College of Engineering, Amravati       Amravati
# 3         Government College of Engineering, Amravati       Amravati
# 4         Government College of Engineering, Amravati       Amravati
# 5         Government College of Engineering, Amravati       Amravati
# 6         Government College of Engineering, Amravati       Amravati
# 7         Government College of Engineering, Amravati       Amravati
# 8        Sant Gadge Baba Amravati University,Amravati       Amravati
# 9        Sant Gadge Baba Amravati University,Amravati       Amravati
# 10       Sant Gadge Baba Amravati University,Amravati       Amravati
# 11                                                NaN            NaN
# 12                                                NaN            NaN
# 13                                                NaN            NaN
# 14                                                NaN            NaN
# 15                                                NaN            NaN
# 16                                                NaN            NaN
# 17                                                NaN            NaN
# 18       Sant Gadge Baba Amravati University,Amravati       Amravati
# 19       Sant Gadge Baba Amravati University,Amravati       Amravati
# 20       Sant Gadge Baba Amravati University,Amravati       Amravati
# 21       Sant Gadge Baba Amravati University,Amravati       Amravati
# 22       Sant Gadge Baba Amravati University,Amravati       Amravati
# 23       Sant Gadge Baba Amravati University,Amravati       Amravati
# 24       Sant Gadge Baba Amravati University,Amravati       Amravati
# 25       Sant Gadge Baba Amravati University,Amravati       Amravati
# 26  Shri Shivaji Education Society's College of En...          Akola
# 27  Shri Shivaji Education Society's College of En...          Akola
# 28  Shri Shivaji Education Society's College of En...          Akola
# 29  Shri Shivaji Education Society's College of En...          Akola
# 30  Shri Shivaji Education Society's College of En...          Akola
# 31  Shri Shivaji Education Society's College of En...          Akola
# 32  Shri Shivaji Education Society's College of En...          Akola
# 33  Shri Shivaji Education Society's College of En...          Akola
# 34  Shri Shivaji Education Society's College of En...          Akola
# 35  Shri Shivaji Education Society's College of En...          Akola
# 36  Shri Shivaji Education Society's College of En...          Akola
# 37                                                NaN            NaN
# 38                                                NaN            NaN
# 39                                                NaN            NaN
# 40                                                NaN            NaN
# 41                                                NaN            NaN
# 42                                                NaN            NaN
# 43                                                NaN            NaN
# 44                                                NaN            NaN
# 45                                                NaN            NaN
# 46                                                NaN            NaN
# 47                                                NaN            NaN
# 48                                                NaN            NaN
# 49                                                NaN            NaN

# %%
dataframe=dataframe[["Merit No","Marks","Application ID","Name of Candidate","Gender","Category","Category id","Seat Type","PWD/DEF","Sub Group","sub group name","cource_code","cource code name","college_code","Institute dict","Institute Name","Seat conformation"]]

# %%
dataframe.head()
# Out:
#    Merit No  Marks  Application ID           Name of Candidate Gender  \
# 0        60  95.13        19106856  PAWAR SIDDHI RAVINDRASINGH      F
# 1       213  93.38        19126045   MAHALLE SHRADDHA MOHANRAO      F
# 2       384  92.47        19105661        TUSHAR RAJESH LAHANE      M
# 3       420  92.31        19103256         RAUT PALASH SUBHASH      M
# 4       465  92.12        19147230   INGLE DHANASHRI VIJAYSINH      F
#
#   Category  Category id Seat Type PWD/DEF  Sub Group sub group name  \
# 0     OPEN            1     LOPEN     NaN        201          Civil
# 1      OBC            2     GOPEN     NaN        201          Civil
# 2      OBC            2      GOBC     NaN        201          Civil
# 3      OBC            2      GOBC     NaN        201          Civil
# 4     SEBC            3     GSEBC     NaN        201          Civil
#
#    cource_code cource code name  college_code Institute dict  \
# 0          201            Civil          1002       Amravati
# 1          201            Civil          1002       Amravati
# 2          201            Civil          1002       Amravati
# 3          201            Civil          1002       Amravati
# 4          201            Civil          1002       Amravati
#
#                                 Institute Name Seat conformation
# 0  Government College of Engineering, Amravati
# 1  Government College of Engineering, Amravati
# 2  Government College of Engineering, Amravati
# 3  Government College of Engineering, Amravati
# 4  Government College of Engineering, Amravati

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75031 entries, 0 to 75030
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Merit No           75031 non-null  int64
#  1   Marks              75031 non-null  float64
#  2   Application ID     75031 non-null  int64
#  3   Name of Candidate  75031 non-null  object
#  4   Gender             75031 non-null  object
#  5   Category           38927 non-null  object
#  6   Category id        75031 non-null  int64
#  7   Seat Type          75031 non-null  object
#  8   PWD/DEF            81 non-null     object
#  9   Sub Group          75031 non-null  int64
#  10  sub group name     38872 non-null  object
#  11  cource_code        75031 non-null  int64
#  12  cource code name   38911 non-null  object
#  13  college_code       75031 non-null  int64
#  14  Institute dict     38927 non-null  object
#  15  Institute Name     38927 non-null  object
#  16  Seat conformation  75031 non-null  object
# dtypes: float64(1), int64(6), object(10)
# memory usage: 9.7+ MB

# %%
dataframe.to_csv("../../data/processed/cap-1.csv")
