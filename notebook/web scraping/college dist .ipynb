# %%
import pandas as pd
import requests
import time
import numpy as np
from bs4 import BeautifulSoup

dataframe=pd.read_csv("../final data/college maping.csv")
dataframe.head()
# Out:
#    Unnamed: 0  Institute Code  \
# 0           0            1002
# 1           1            1005
# 2           2            1012
# 3           3            1101
# 4           4            1105
#
#                                       Institute Name
# 0        Government College of Engineering, Amravati
# 1       Sant Gadge Baba Amravati University,Amravati
# 2           Government Engineering College, Yavatmal
# 3  Shri Sant Gajanan Maharaj College of Engineeri...
# 4  Prof. Ram Meghe Institute of Technology & Rese...

# %%
length=dataframe.shape
dataframe["Institute dict"]=np.nan

# %%
for i in range(length[0]):
    url="http://www.dtemaharashtra.gov.in/frmInstituteSummary.aspx?InstituteCode={}".format(dataframe["Institute Code"].iloc[i])
    r=requests.get(url)
    html_conent=r.content
    soup=BeautifulSoup(html_conent,'html.parser')
    classs=soup.find(id="ctl00_ContentPlaceHolder1_lblDistrict")
    dataframe["Institute dict"].iloc[i]=classs.text
    time.sleep(3)
# Out:
# C:\Users\sai\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
dataframe.head(100)
# Out:
#     Unnamed: 0  Institute Code  \
# 0            0            1002
# 1            1            1005
# 2            2            1012
# 3            3            1101
# 4            4            1105
# ..         ...             ...
# 95          95            3214
# 96          96            3215
# 97          97            3216
# 98          98            3217
# 99          99            3218
#
#                                        Institute Name   Institute dict
# 0         Government College of Engineering, Amravati         Amravati
# 1        Sant Gadge Baba Amravati University,Amravati         Amravati
# 2            Government Engineering College, Yavatmal         Yavatmal
# 3   Shri Sant Gajanan Maharaj College of Engineeri...         Buldhana
# 4   Prof. Ram Meghe Institute of Technology & Rese...         Amravati
# ..                                                ...              ...
# 95  Xavier Institute Of Engineering C/O Xavier Tec...      Mumbai City
# ...

# %%
dataframe.drop(["Unnamed: 0","Institute Name"],axis=1,inplace=True)

# %%
dataframe.to_csv("../final data/college town.csv")
